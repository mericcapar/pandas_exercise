# %%
import numpy as np
import pandas as pd
import datetime

# %%
url = 'https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data'
data = pd.read_csv(url , sep= '\s+' , parse_dates = [0,1,2])
data.head()
# Out:
# /var/folders/yv/1m17xqnn627c244891_7878r0000gn/T/ipykernel_62456/2114807744.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data = pd.read_csv(url , sep= '\s+' , parse_dates = [0,1,2] )
# /var/folders/yv/1m17xqnn627c244891_7878r0000gn/T/ipykernel_62456/2114807744.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data = pd.read_csv(url , sep= '\s+' , parse_dates = [0,1,2] )
# /var/folders/yv/1m17xqnn627c244891_7878r0000gn/T/ipykernel_62456/2114807744.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   data = pd.read_csv(url , sep= '\s+' , parse_dates = [0,1,2] )
#    Yr Mo Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  61  1  1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  61  1  2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  61  1  3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  61  1  4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  61  1  5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83
